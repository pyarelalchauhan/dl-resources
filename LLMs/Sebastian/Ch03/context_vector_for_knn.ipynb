     [-0.87190986, 0.24349408, -0.21285935, -0.6724988, -0.7268599, -0.5882094, 0.9803735, -0.12319456, 0.6540617, 0.75362253, 0.29674464, 0.9545598, 0.126747, 0.99186707, 0.053570118, 0.9985521, 0.8660475, 0.39327696, -0.8455171, 0.21237773, -0.6870979, -0.21925639, 0.9164404, -0.20809104, 0.675985, 0.7218857, 0.31116906, 0.9482814, 0.13324091, 0.9907299, 0.05633973, 0.9983492, 0.77196884, 0.5763471, 0.23768327, 0.55688983, 0.30954412, 0.82973325, 0.15782869, 0.9656113, 0.068802014, 0.9937464, 0.029184792, 0.99888355, 0.012320002, 0.99980134, 0.0051962677, 0.9999647],
     [-0.20943429, 0.75224406, -0.4902848, -0.581408, -0.8396331, -0.44528377, 0.96964216, -0.20449446, 0.6804202, 0.7306208, 0.31085598, 0.95015514, 0.13293241, 0.99107367, 0.056196228, 0.9984107, 0.76120055, 0.13991211, -0.7448305, 0.258523, -0.7251378, -0.21853101, 0.9208482, -0.23184231, 0.6850399, 0.715851, 0.3156688, 0.9471415, 0.13519166, 0.990525, 0.057166368, 0.99831265, 0.9347577, 0.013457477, 0.3488774, 0.48991805, 0.3949136, 0.7845554, 0.2030473, 0.9556235, 0.08868861, 0.9919019, 0.037634064, 0.99855334, 0.015887791, 0.99974257, 0.006701149, 0.9999542],
     [-0.29278994, 0.59897435, -0.4892159, -0.647335, -0.8479326, -0.45565546, 0.9721144, -0.20373306, 0.68036187, 0.73122877, 0.31070042, 0.950282, 0.13285625, 0.9910968, 0.056163304, 0.9984148, 0.7106766, 0.093569875, -0.7147786, 0.26969212, -0.7372496, -0.21389213, 0.92140347, -0.2401991, 0.6880724, 0.7136134, 0.31721857, 0.9467157, 0.13586643, 0.9904484, 0.057452522, 0.99829906, 0.9008883, -0.37042916, 0.46148503, 0.39622557, 0.4583161, 0.7616593, 0.23207664, 0.9511911, 0.1011249, 0.99110097, 0.042893335, 0.99841046, 0.01810673, 0.9997171, 0.007636953, 0.9999497]
    ]
)

# %%
inputs.shape
# Out:
# torch.Size([12, 48])

# %%
center_point_c1 = inputs[0]
attn_scores_c1 = torch.empty(inputs.shape[0])
for i, x_i in enumerate(inputs):
    attn_scores_c1[i] = torch.dot(x_i, center_point_c1)
print(attn_scores_c1)
# Out:
# tensor([21.1681, 21.1398, 20.4776, 21.1736, 21.2013, 20.4679, 20.9030, 20.3765,
#         20.9106, 20.9037, 20.7110, 20.3721])

# %%
attn_scores_c1.shape
# Out:
# torch.Size([12])

# %%
attn_weights_c1 = torch.softmax(attn_scores_c1,dim=0)
print(attn_weights_c1) # this much importance needs to be given to other neighbours
# Out:
# tensor([0.1129, 0.1098, 0.0566, 0.1136, 0.1167, 0.0561, 0.0866, 0.0512, 0.0873,
#         0.0867, 0.0715, 0.0509])

# %%
center_point_c1 = inputs[0] #The first input token
context_vec_c1 = torch.empty(center_point_c1.shape)
for i, x_i in enumerate(inputs):
    context_vec_c1 += attn_weights_c1[i] * x_i
print(context_vec_c1)
# Out:
# tensor([-0.5044,  0.6294, -0.3858, -0.5946, -0.7914, -0.4992,  0.9731, -0.1718,
#          0.6698,  0.7397,  0.3052,  0.9519,  0.1305,  0.9914,  0.0551,  0.9985,
#          0.8098,  0.3164, -0.8079,  0.2197, -0.7003, -0.2229,  0.9186, -0.2151,
#          0.6788,  0.7202,  0.3125,  0.9480,  0.1338,  0.9907,  0.0566,  0.9983,
#          0.8348,  0.3102,  0.3032,  0.5154,  0.3522,  0.8109,  0.1791,  0.9616,
#          0.0781,  0.9930,  0.0331,  0.9988,  0.0140,  0.9998,  0.0059,  1.0000])

# %%
attn_weights_c1_stablemax = torch.softmax(g(attn_scores_c1),dim=0)
print(attn_weights_c1_stablemax) # this much importance needs to be given to other neighbours
# Out:
# tensor([0.0847, 0.0846, 0.0820, 0.0847, 0.0848, 0.0820, 0.0837, 0.0817, 0.0837,
#         0.0837, 0.0829, 0.0816])

# %%
center_point_c1 = inputs[0] #The first input token
context_vec_c1_stablemax = torch.empty(center_point_c1.shape)
for i, x_i in enumerate(inputs):
    context_vec_c1_stablemax += attn_weights_c1_stablemax[i] * x_i
print(context_vec_c1_stablemax)
print(context_vec_c1_stablemax.sum(dim=0))
# Out:
# tensor([-0.4729,  0.6120, -0.3944, -0.6038, -0.7978, -0.4952,  0.9731, -0.1752,
#          0.6709,  0.7388,  0.3058,  0.9517,  0.1307,  0.9914,  0.0553,  0.9985,
#          0.7894,  0.2991, -0.7959,  0.2197, -0.7050, -0.2248,  0.9195, -0.2173,
#          0.6796,  0.7197,  0.3129,  0.9479,  0.1340,  0.9907,  0.0567,  0.9983,
#          0.8460,  0.2134,  0.3236,  0.5000,  0.3668,  0.8036,  0.1866,  0.9600,
#          0.0813,  0.9927,  0.0345,  0.9987,  0.0146,  0.9998,  0.0061,  1.0000])
# tensor(16.9410)

# %%
neighbours_embedding_mean = inputs.mean(dim=0)
print(neighbours_embedding_mean)
print(neighbours_embedding_mean.sum(dim=0))
# Out:
# tensor([-0.4711,  0.6113, -0.3949, -0.6042, -0.7982, -0.4949,  0.9731, -0.1754,
#          0.6710,  0.7388,  0.3058,  0.9517,  0.1307,  0.9914,  0.0553,  0.9985,
#          0.7883,  0.2982, -0.7953,  0.2197, -0.7052, -0.2249,  0.9195, -0.2174,
#          0.6797,  0.7197,  0.3129,  0.9479,  0.1340,  0.9907,  0.0567,  0.9983,
#          0.8466,  0.2082,  0.3247,  0.4991,  0.3675,  0.8032,  0.1870,  0.9599,
#          0.0815,  0.9927,  0.0346,  0.9987,  0.0146,  0.9998,  0.0062,  1.0000])
# tensor(16.9359)

# %%
dims = np.arange(len(center_point_c1))

plt.figure(figsize=(12, 5))
plt.plot(dims, center_point_c1, marker='o', label='P1 (C1) Embedding', color='blue')
plt.plot(dims, context_vec_c1, marker='s', label='P1 Context (Attention)', color='red')
plt.plot(dims, context_vec_c1_stablemax, marker='^', label='P1 Context (Stablemax)', color='green')
plt.plot(dims, neighbours_embedding_mean, marker='d', label='Neighbour Mean', color='purple', linestyle='--')

plt.title("Embedding Values Across Dimensions for Central Point (P1/C1)")
plt.xlabel("Embedding Dimension")
plt.ylabel("Embedding Value")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###
#         [-0.0034, -0.0025, -0.0015],
#         [ 0.0148,  0.0053,  0.0249],
#         [-0.0216,  0.0016, -0.0119],
#         [-0.0154,  0.0012,  0.0289],
#         [-0.0299,  0.0109,  0.0007],
#         [-0.0278,  0.0029, -0.0035],
#         [ 0.0047,  0.0076,  0.0160],
#         [ 0.0002,  0.0097,  0.0315]])

# %% [markdown]
# Encode Relative Positions using Random Fourier Features

# %%
inputs

# %%
# using the matrix multiplication
attn_scores = inputs @ inputs.T
print(attn_scores)
# Out:
# tensor([[21.1681, 21.1398, 20.4776, 21.1736, 21.2013, 20.4679, 20.9030, 20.3765,
#          20.9106, 20.9037, 20.7110, 20.3721],
#         [21.1398, 21.1345, 20.5049, 21.1456, 21.1604, 20.5326, 20.7913, 20.3366,
#          20.7921, 20.7797, 20.7368, 20.3873],
#         [20.4776, 20.5049, 20.6978, 20.4739, 20.4292, 20.6107, 19.9579, 20.5001,
#          20.0817, 20.0339, 20.5684, 20.5945],
#         [21.1736, 21.1456, 20.4739, 21.3349, 21.1862, 20.5409, 20.9437, 20.4767,
#          21.0967, 21.0007, 20.8213, 20.5132],
#         [21.2013, 21.1604, 20.4292, 21.1862, 21.2584, 20.3934, 21.0026, 20.3614,
#          20.9922, 21.0032, 20.6693, 20.3058],
#         [20.4679, 20.5326, 20.6107, 20.5409, 20.3934, 20.6861, 19.8564, 20.3368,
#          19.9923, 19.8994, 20.6229, 20.5607],
#         [20.9030, 20.7913, 19.9579, 20.9437, 21.0026, 19.8564, 21.0543, 20.1668,
#          21.0963, 21.0985, 20.2592, 19.9378],
#         [20.3765, 20.3366, 20.5001, 20.4767, 20.3614, 20.3368, 20.1668, 20.6136,
# ...

# %%
attn_weights = torch.softmax(attn_scores, dim=1)
print(attn_weights)
# Out:
# tensor([[0.1129, 0.1098, 0.0566, 0.1136, 0.1167, 0.0561, 0.0866, 0.0512, 0.0873,
#          0.0867, 0.0715, 0.0509],
#         [0.1137, 0.1131, 0.0603, 0.1144, 0.1161, 0.0620, 0.0803, 0.0509, 0.0803,
#          0.0793, 0.0760, 0.0536],
#         [0.0868, 0.0892, 0.1082, 0.0865, 0.0827, 0.0992, 0.0516, 0.0888, 0.0584,
#          0.0557, 0.0951, 0.0976],
#         [0.1056, 0.1027, 0.0525, 0.1241, 0.1070, 0.0561, 0.0839, 0.0526, 0.0978,
#          0.0889, 0.0743, 0.0546],
#         [0.1138, 0.1092, 0.0526, 0.1121, 0.1204, 0.0507, 0.0933, 0.0491, 0.0923,
#          0.0933, 0.0668, 0.0465],
#         [0.0882, 0.0941, 0.1017, 0.0949, 0.0818, 0.1097, 0.0478, 0.0773, 0.0548,
#          0.0499, 0.1030, 0.0968],
#         [0.1025, 0.0917, 0.0398, 0.1067, 0.1132, 0.0360, 0.1192, 0.0491, 0.1243,
#          0.1246, 0.0538, 0.0390],
#         [0.0801, 0.0770, 0.0907, 0.0886, 0.0789, 0.0770, 0.0650, 0.1016, 0.0854,
#          0.0778, 0.0841, 0.0939],
# ...

# %%
# stablemax - for numerical stability
def g(x):
    return torch.where(
        x>=0,
        torch.log(x+1),
        -torch.log(-x+1)
    )

# %%
# normalizing using the stablemax
attn_weights_stablemax = torch.softmax(g(attn_scores), dim=1)
print(attn_weights_stablemax)
print(attn_weights_stablemax.sum(dim=1))
# Out:
# tensor([[0.0847, 0.0846, 0.0820, 0.0847, 0.0848, 0.0820, 0.0837, 0.0817, 0.0837,
#          0.0837, 0.0829, 0.0816],
#         [0.0847, 0.0847, 0.0823, 0.0847, 0.0848, 0.0824, 0.0834, 0.0816, 0.0834,
#          0.0833, 0.0831, 0.0818],
#         [0.0836, 0.0837, 0.0844, 0.0836, 0.0834, 0.0841, 0.0816, 0.0837, 0.0821,
#          0.0819, 0.0839, 0.0840],
#         [0.0844, 0.0843, 0.0817, 0.0850, 0.0845, 0.0820, 0.0835, 0.0818, 0.0841,
#          0.0837, 0.0831, 0.0819],
#         [0.0847, 0.0846, 0.0818, 0.0847, 0.0850, 0.0817, 0.0840, 0.0815, 0.0840,
#          0.0840, 0.0827, 0.0813],
#         [0.0837, 0.0839, 0.0843, 0.0840, 0.0834, 0.0845, 0.0813, 0.0832, 0.0818,
#          0.0815, 0.0843, 0.0841],
#         [0.0845, 0.0841, 0.0809, 0.0847, 0.0849, 0.0805, 0.0851, 0.0817, 0.0853,
#          0.0853, 0.0821, 0.0808],
#         [0.0832, 0.0830, 0.0837, 0.0836, 0.0831, 0.0831, 0.0824, 0.0841, 0.0835,
#          0.0831, 0.0834, 0.0838],
# ...

# %%
# context vector via matrix multiplication
all_context_vecs = attn_weights @ inputs
print(all_context_vecs)
# Out:
# tensor([[-0.5044,  0.6294, -0.3858, -0.5946, -0.7914, -0.4992,  0.9731, -0.1718,
#           0.6698,  0.7397,  0.3052,  0.9519,  0.1305,  0.9914,  0.0551,  0.9985,
#           0.8098,  0.3164, -0.8079,  0.2197, -0.7003, -0.2229,  0.9186, -0.2151,
#           0.6788,  0.7202,  0.3125,  0.9480,  0.1338,  0.9907,  0.0566,  0.9983,
#           0.8348,  0.3102,  0.3032,  0.5154,  0.3522,  0.8109,  0.1791,  0.9616,
#           0.0781,  0.9930,  0.0331,  0.9988,  0.0140,  0.9998,  0.0059,  1.0000],
#         [-0.4910,  0.6397, -0.3915, -0.5920, -0.7935, -0.4961,  0.9729, -0.1735,
#           0.6703,  0.7393,  0.3055,  0.9518,  0.1306,  0.9914,  0.0552,  0.9985,
#           0.8064,  0.3137, -0.8059,  0.2195, -0.7011, -0.2234,  0.9188, -0.2154,
#           0.6789,  0.7202,  0.3126,  0.9480,  0.1338,  0.9907,  0.0566,  0.9983,
#           0.8384,  0.2967,  0.3066,  0.5133,  0.3543,  0.8099,  0.1802,  0.9614,
#           0.0785,  0.9930,  0.0333,  0.9987,  0.0141,  0.9998,  0.0059,  1.0000],
# ...

# %%
# Contex vector with respect to the stablemax
all_context_vecs_stablemax = attn_weights_stablemax @ inputs
print(all_context_vecs)
# Out:
# tensor([[-0.5044,  0.6294, -0.3858, -0.5946, -0.7914, -0.4992,  0.9731, -0.1718,
#           0.6698,  0.7397,  0.3052,  0.9519,  0.1305,  0.9914,  0.0551,  0.9985,
#           0.8098,  0.3164, -0.8079,  0.2197, -0.7003, -0.2229,  0.9186, -0.2151,
#           0.6788,  0.7202,  0.3125,  0.9480,  0.1338,  0.9907,  0.0566,  0.9983,
#           0.8348,  0.3102,  0.3032,  0.5154,  0.3522,  0.8109,  0.1791,  0.9616,
#           0.0781,  0.9930,  0.0331,  0.9988,  0.0140,  0.9998,  0.0059,  1.0000],
#         [-0.4910,  0.6397, -0.3915, -0.5920, -0.7935, -0.4961,  0.9729, -0.1735,
#           0.6703,  0.7393,  0.3055,  0.9518,  0.1306,  0.9914,  0.0552,  0.9985,
#           0.8064,  0.3137, -0.8059,  0.2195, -0.7011, -0.2234,  0.9188, -0.2154,
#           0.6789,  0.7202,  0.3126,  0.9480,  0.1338,  0.9907,  0.0566,  0.9983,
#           0.8384,  0.2967,  0.3066,  0.5133,  0.3543,  0.8099,  0.1802,  0.9614,
#           0.0785,  0.9930,  0.0333,  0.9987,  0.0141,  0.9998,  0.0059,  1.0000],
# ...

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# If your context vectors are still torch tensors, convert to numpy
inputs_np = inputs.detach().cpu().numpy()
context_vecs_np = all_context_vecs.detach().cpu().numpy()
context_vecs_stablemax_np = all_context_vecs_stablemax.detach().cpu().numpy()

# Stack all points to fit PCA on whole data
all_data = np.vstack([inputs_np, context_vecs_np, context_vecs_stablemax_np])

# Project to 2D using PCA
pca = PCA(n_components=2)
all_data_2d = pca.fit_transform(all_data)

# Split them back
n = inputs_np.shape[0]
inputs_2d = all_data_2d[:n]
context_2d = all_data_2d[n:2*n]
stablemax_2d = all_data_2d[2*n:]

# Plotting
plt.figure(figsize=(8,6))

plt.scatter(inputs_2d[:,0], inputs_2d[:,1], color='blue', label='Input Embeddings')
plt.scatter(context_2d[:,0], context_2d[:,1], color='red', label='Context Vecs (Attention)')
plt.scatter(stablemax_2d[:,0], stablemax_2d[:,1], color='green', label='Context Vecs (Stablemax)')

# Draw arrows from inputs to each context vector for both methods
for i in range(n):
    plt.arrow(inputs_2d[i,0], inputs_2d[i,1],
              context_2d[i,0]-inputs_2d[i,0], context_2d[i,1]-inputs_2d[i,1],
              color='red', alpha=0.3, head_width=0.02, length_includes_head=True)
    plt.arrow(inputs_2d[i,0], inputs_2d[i,1],
              stablemax_2d[i,0]-inputs_2d[i,0], stablemax_2d[i,1]-inputs_2d[i,1],
              color='green', alpha=0.3, head_width=0.02, length_includes_head=True)

plt.legend()
plt.title("Positional Embedding Transformation via Attention (PCA Projection)")
plt.xlabel("PCA-1")
plt.ylabel("PCA-2")
plt.tight_layout()
plt.show()

# %%
# Suppose you have 12 tokens:
token_labels = ["P1 (C1)", "P2", "P3", "P4", "P5", "P6", "P7", "P8", "P9", "P10", "P11", "P12"]
n = len(token_labels)  # Should match your n from before

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# Example: define inputs, all_context_vecs, all_context_vecs_stablemax
# (You would use your real data here.)
# inputs = torch.randn(12, 48)
# all_context_vecs = torch.randn(12, 48)
# all_context_vecs_stablemax = torch.randn(12, 48)

# Convert tensors to numpy arrays if necessary
inputs_np = inputs.detach().cpu().numpy()
context_vecs_np = all_context_vecs.detach().cpu().numpy()
context_vecs_stablemax_np = all_context_vecs_stablemax.detach().cpu().numpy()

# Stack for dimensionality reduction
all_data = np.vstack([inputs_np, context_vecs_np, context_vecs_stablemax_np])

# t-SNE projection to 2D
tsne = TSNE(n_components=2, random_state=42, perplexity=5)
all_data_2d = tsne.fit_transform(all_data)

# Split back into groups
n = inputs_np.shape[0]
inputs_2d = all_data_2d[:n]
context_2d = all_data_2d[n:2*n]
stablemax_2d = all_data_2d[2*n:]

# Prepare labels
token_labels = ["P1 (C1)", "P2", "P3", "P4", "P5", "P6", "P7", "P8", "P9", "P10", "P11", "P12"]

# Plot
plt.figure(figsize=(10,7))
plt.scatter(inputs_2d[:,0], inputs_2d[:,1], color='blue', label='Input Embeddings')
plt.scatter(context_2d[:,0], context_2d[:,1], color='red', label='Context Vecs (Attention)')
plt.scatter(stablemax_2d[:,0], stablemax_2d[:,1], color='green', label='Context Vecs (Stablemax)')

# Arrows from inputs to context vectors
for i in range(n):
    plt.arrow(inputs_2d[i,0], inputs_2d[i,1],
              context_2d[i,0]-inputs_2d[i,0], context_2d[i,1]-inputs_2d[i,1],
              color='red', alpha=0.3, head_width=1.5, length_includes_head=True)
    plt.arrow(inputs_2d[i,0], inputs_2d[i,1],
              stablemax_2d[i,0]-inputs_2d[i,0], stablemax_2d[i,1]-inputs_2d[i,1],
              color='green', alpha=0.3, head_width=1.5, length_includes_head=True)

# Annotate each input embedding
for i in range(n):
    plt.annotate(token_labels[i], (inputs_2d[i,0], inputs_2d[i,1]),
                 textcoords="offset points", xytext=(0,10), ha='center', fontsize=9, color='blue', weight='bold')

plt.legend()
plt.title("Positional Embedding Transformation via Attention (t-SNE Projection)")
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.tight_layout()
plt.show()

# %%
# !pip install scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 5.6 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.8/20.8 MB 5.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn] [scikit-learn]
# ...

# %%
import torch

inputs= torch.tensor(
    [[-0.49850854, 0.8297348, -0.42407504, -0.5181521, -0.7892281, -0.47853172, 0.9697392, -0.17709477, 0.6712045, 0.73783463, 0.3061023, 0.95152265, 0.13086021, 0.9913195, 0.055317283, 0.9984545, 0.8195696, 0.42684907, -0.8359185, 0.1852817, -0.68969315, -0.23379323, 0.91921705, -0.20484805, 0.6751708, 0.7231623, 0.31061116, 0.94853544, 0.13298857, 0.990776, 0.05623202, 0.9983575, 0.82662344, 0.46554255, 0.2517241, 0.54790145, 0.32589057, 0.81920654, 0.16711819, 0.9632383, 0.07293037, 0.9933071, 0.030941978, 0.9988048, 0.013062227, 0.99978733, 0.0055093532, 0.9999622],
     [-0.3839049, 0.89070463, -0.4531937, -0.49100003, -0.80001205, -0.4592298, 0.96781445, -0.18679975, 0.67430586, 0.73497695, 0.30779696, 0.9509724, 0.13160524, 0.99122036, 0.055633754, 0.9984368, 0.7932598, 0.39198858, -0.81618625, 0.18390666, -0.6966998, -0.23981841, 0.92109984, -0.20732741, 0.6763008, 0.7227184, 0.3111087, 0.9484569, 0.1331999, 0.990762, 0.056321245, 0.998355, 0.8530762, 0.45626408, 0.277337, 0.539285, 0.33238804, 0.82214373, 0.16871044, 0.9640148, 0.07349966, 0.993454, 0.031174153, 0.9988313, 0.013159539, 0.999792, 0.0055503454, 0.99996305],
     [-0.29278994, 0.59897435, -0.4892159, -0.647335, -0.8479326, -0.45565546, 0.9721144, -0.20373306, 0.68036187, 0.73122877, 0.31070042, 0.950282, 0.13285625, 0.9910968, 0.056163304, 0.9984148, 0.7106766, 0.093569875, -0.7147786, 0.26969212, -0.7372496, -0.21389213, 0.92140347, -0.2401991, 0.6880724, 0.7136134, 0.31721857, 0.9467157, 0.13586643, 0.9904484, 0.057452522, 0.99829906, 0.9008883, -0.37042916, 0.46148503, 0.39622557, 0.4583161, 0.7616593, 0.23207664, 0.9511911, 0.1011249, 0.99110097, 0.042893335, 0.99841046, 0.01810673, 0.9997171, 0.007636953, 0.9999497]
    ]
)

# %%
inputs.shape
# Out:
# torch.Size([12, 48])

# %%
att_score = inputs @ inputs.T
att_score.shape
# Out:
# torch.Size([12, 12])

# %%
att_weights = torch.softmax(att_score, dim = 1)

att_weights.shape
# Out:
# torch.Size([12, 12])

# %%
inputs.shape
# Out:
# torch.Size([12, 48])

# %%
context_vec_posE = att_weights @ inputs 
context_vec_posE.shape
# Out:
# torch.Size([12, 48])

# %%
context_vec_posE
# Out:
# tensor([[-0.5044,  0.6294, -0.3858, -0.5946, -0.7914, -0.4992,  0.9731, -0.1718,
#           0.6698,  0.7397,  0.3052,  0.9519,  0.1305,  0.9914,  0.0551,  0.9985,
#           0.8098,  0.3164, -0.8079,  0.2197, -0.7003, -0.2229,  0.9186, -0.2151,
#           0.6788,  0.7202,  0.3125,  0.9480,  0.1338,  0.9907,  0.0566,  0.9983,
#           0.8348,  0.3102,  0.3032,  0.5154,  0.3522,  0.8109,  0.1791,  0.9616,
#           0.0781,  0.9930,  0.0331,  0.9988,  0.0140,  0.9998,  0.0059,  1.0000],
#         [-0.4910,  0.6397, -0.3915, -0.5920, -0.7935, -0.4961,  0.9729, -0.1735,
#           0.6703,  0.7393,  0.3055,  0.9518,  0.1306,  0.9914,  0.0552,  0.9985,
#           0.8064,  0.3137, -0.8059,  0.2195, -0.7011, -0.2234,  0.9188, -0.2154,
#           0.6789,  0.7202,  0.3126,  0.9480,  0.1338,  0.9907,  0.0566,  0.9983,
#           0.8384,  0.2967,  0.3066,  0.5133,  0.3543,  0.8099,  0.1802,  0.9614,
#           0.0785,  0.9930,  0.0333,  0.9987,  0.0141,  0.9998,  0.0059,  1.0000],
# ...

# %%
# stable amx version.
def g(x):
    return torch.where(
        x>=0,
        torch.log(x+1),
        -torch.log(-x+1)
    )

def contex_vec_v1(x):
    attn_score = x @ x.T
    attn_weights= torch.softmax(g(attn_scores) , dim = -1)
    context_vec = att_weights @ x
    return context_vec

# %%
def context_vec(x):
    attn_scores = x @ x.T
    attn_weights= torch.softmax(attn_scores , dim = -1)
    context_vec = attn_weights @ x
    return context_vec

# %%
import torch

def context_vec_v1(x):
    """
    Computes the context vector using a custom non-linearity on attention scores,
    softmax, and weighted sum—all in one function.
    """
    def g(x):
        return torch.where(
            x >= 0,
     [-0.87190986, 0.24349408, -0.21285935, -0.6724988, -0.7268599, -0.5882094, 0.9803735, -0.12319456, 0.6540617, 0.75362253, 0.29674464, 0.9545598, 0.126747, 0.99186707, 0.053570118, 0.9985521, 0.8660475, 0.39327696, -0.8455171, 0.21237773, -0.6870979, -0.21925639, 0.9164404, -0.20809104, 0.675985, 0.7218857, 0.31116906, 0.9482814, 0.13324091, 0.9907299, 0.05633973, 0.9983492, 0.77196884, 0.5763471, 0.23768327, 0.55688983, 0.30954412, 0.82973325, 0.15782869, 0.9656113, 0.068802014, 0.9937464, 0.029184792, 0.99888355, 0.012320002, 0.99980134, 0.0051962677, 0.9999647],
     [-0.20943429, 0.75224406, -0.4902848, -0.581408, -0.8396331, -0.44528377, 0.96964216, -0.20449446, 0.6804202, 0.7306208, 0.31085598, 0.95015514, 0.13293241, 0.99107367, 0.056196228, 0.9984107, 0.76120055, 0.13991211, -0.7448305, 0.258523, -0.7251378, -0.21853101, 0.9208482, -0.23184231, 0.6850399, 0.715851, 0.3156688, 0.9471415, 0.13519166, 0.990525, 0.057166368, 0.99831265, 0.9347577, 0.013457477, 0.3488774, 0.48991805, 0.3949136, 0.7845554, 0.2030473, 0.9556235, 0.08868861, 0.9919019, 0.037634064, 0.99855334, 0.015887791, 0.99974257, 0.006701149, 0.9999542],
     [-0.29278994, 0.59897435, -0.4892159, -0.647335, -0.8479326, -0.45565546, 0.9721144, -0.20373306, 0.68036187, 0.73122877, 0.31070042, 0.950282, 0.13285625, 0.9910968, 0.056163304, 0.9984148, 0.7106766, 0.093569875, -0.7147786, 0.26969212, -0.7372496, -0.21389213, 0.92140347, -0.2401991, 0.6880724, 0.7136134, 0.31721857, 0.9467157, 0.13586643, 0.9904484, 0.057452522, 0.99829906, 0.9008883, -0.37042916, 0.46148503, 0.39622557, 0.4583161, 0.7616593, 0.23207664, 0.9511911, 0.1011249, 0.99110097, 0.042893335, 0.99841046, 0.01810673, 0.9997171, 0.007636953, 0.9999497]
    ]
)

# %%
inputs.shape
# Out:
# torch.Size([12, 48])

# %%
batched = inputs.view(batch_size, num_tokens, emb_size)
print(batched.shape)  # torch.Size([2, 6, 48])
# Out:
# torch.Size([2, 6, 48])

# %%
context_vec = context_vec(batched)
context_vec
# Out:
# /var/folders/44/j5v5d8ds2f194j6hlrb9n4gc0000gn/T/ipykernel_1264/1981193448.py:2: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:4416.)
#   attn_scores = x @ x.T
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 context_vec = context_vec(batched)
#       2 context_vec
#
# Cell In[7], line 2, in context_vec(x)
#       1 def context_vec(x):
# ----> 2     attn_scores = x @ x.T
#       3     attn_weights= torch.softmax(attn_scores , dim = -1)
#       4     context_vec = attn_weights @ x
#
# ...
